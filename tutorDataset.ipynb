# %%
import csv
import torch
import pandas as pd

# %%
data_path = "tutor.csv"

# %%
df = pd.read_csv(data_path, nrows=20)

# %%
display(df)
# Out:
#          Username              Full Name Gender  \
# 0    reginaldwood           Curtis Smith      M
# 1        hwinters       Mr. Walter Lopez      M
# 2   richardobrien          Olivia Morgan      F
# 3         sarah18        Brian Rivas DDS      M
# 4        dleblanc             Dean Floyd      M
# 5    natashaclark            Robert Ryan      M
# 6      emilylopez          Zachary Bryan      M
# 7     andrewallen    Jessica Christensen      F
# 8       rebecca72       Cassidy Martinez      F
# 9    heathercurry           Alicia Smith      F
# 10        abrooks        Joshua Faulkner      M
# 11      zbautista        Christine Silva      F
# 12  rhondahouston          Tabitha Casey      F
# 13   colejennifer        Valerie Nichols      F
# 14        brian11        Daniel Delacruz      M
# 15   brandonriley  Mrs. Briana Harmon MD      F
# 16        gwright       Brittany Mathews      F
# 17       tjohnson              Misty Kim      F
# ...

# %%
import torch.utils.data as data_utils
pd.to_numeric(df["Random Number"])
sessions_df = pd.DataFrame(df["Random Number"])
train_tensor = torch.tensor(sessions_df["Random Number"].values)
print(train_tensor)
print(type(train_tensor))
# Out:
# tensor([ 21,  59,   5,   2,   3,   2,   9,   2,   7,  34,  64,  12,  97, 344,
#          37, 844, 278,  84, 389,  33])
# <class 'torch.Tensor'>
